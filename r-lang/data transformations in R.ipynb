# %%
library(nycflights13)
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
flights
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %%
jan <- filter(flights, month == 1, day == 1)

# %%
jan
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1     1   517      515             2         830      819
# 2   2013 1     1   533      529             4         850      830
# 3   2013 1     1   542      540             2         923      850
# 4   2013 1     1   544      545            -1        1004     1022
# 5   2013 1     1   554      600            -6         812      837
# 6   2013 1     1   554      558            -4         740      728
# 7   2013 1     1   555      600            -5         913      854
# 8   2013 1     1   557      600            -3         709      723
# 9   2013 1     1   557      600            -3         838      846
# 10  2013 1     1   558      600            -2         753      745
# 11  2013 1     1   558      600            -2         849      851
# 12  2013 1     1   558      600            -2         853      856
# 13  2013 1     1   558      600            -2         924      917
# ...

# %%
(dec25 <- filter(flights, month == 12, day == 25))
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 12    25  456      500            -4         649      651
# 2   2013 12    25  524      515             9         805      814
# 3   2013 12    25  542      540             2         832      850
# 4   2013 12    25  546      550            -4        1022     1027
# 5   2013 12    25  556      600            -4         730      745
# 6   2013 12    25  557      600            -3         743      752
# 7   2013 12    25  557      600            -3         818      831
# 8   2013 12    25  559      600            -1         855      856
# 9   2013 12    25  559      600            -1         849      855
# 10  2013 12    25  600      600             0         850      846
# 11  2013 12    25  600      600             0         715      723
# 12  2013 12    25  601      600             1         855      905
# 13  2013 12    25  601      600             1         846      849
# ...

# %%
df <- tibble(x = c(1, NA, 3))

# %%
df
# Out:
#   x
# 1  1
# 2 NA
# 3  3

# %%
filter(df, x > 1)
# Out:
#   x
# 1 3

# %%
filter(df, is.na(x) | x > 1)
# Out:
#   x
# 1 NA
# 2  3

# %% [markdown]
# ## arrival delay of 2 hours or more

# %%
flights
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %%
filter(flights, arr_time - sched_arr_time >= 200)
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1    811      630           101       1047      830
# 2    2013 1     1    957      733           144       1056      853
# 3    2013 1     1   1114      900           134       1447     1222
# 4    2013 1     1   1505     1310           115       1638     1431
# 5    2013 1     1   1525     1340           105       1831     1626
# 6    2013 1     1   1528     1459            29       2002     1647
# 7    2013 1     1   1549     1445            64       1912     1656
# 8    2013 1     1   1558     1359           119       1718     1515
# 9    2013 1     1   1732     1630            62       2028     1825
# 10   2013 1     1   1803     1620           103       2008     1750
# 11   2013 1     1   1815     1325           290       2120     1542
# 12   2013 1     1   1842     1422           260       1958     1535
# 13   2013 1     1   1856     1645           131       2212     2005
# ...

# %% [markdown]
# ## flew to houston

# %%
filter(flights, dest == "IAH" | dest == "HOU")
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1    517      515             2        830      819
# 2    2013 1     1    533      529             4        850      830
# 3    2013 1     1    623      627            -4        933      932
# 4    2013 1     1    728      732            -4       1041     1038
# 5    2013 1     1    739      739             0       1104     1038
# 6    2013 1     1    908      908             0       1228     1219
# 7    2013 1     1   1028     1026             2       1350     1339
# 8    2013 1     1   1044     1045            -1       1352     1351
# 9    2013 1     1   1114      900           134       1447     1222
# 10   2013 1     1   1205     1200             5       1503     1505
# 11   2013 1     1   1208     1158            10       1540     1502
# 12   2013 1     1   1248     1250            -2       1607     1607
# 13   2013 1     1   1306     1300             6       1622     1610
# ...

# %%
1 + x != 1
# Out:
# [1] TRUE

# %%
x
# Out:
# [1] 1

# %%
head(flights)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %% [markdown]
# ### Arrived more than two hours late, but didn’t leave late

# %%
filter(flights,
       abs(dep_delay) < 60 & arr_delay > 200)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 12     8  1905     1807           58        2314     1950
# 2 2013  7    22  2009     1910           59         130     2206
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 204       UA      708    N489UA  EWR    ORD  135       719     18    7
# 2 204       UA      518    N553UA  EWR    LAX  334      2454     19   10
#   time_hour
# 1 2013-12-08 18:00:00
# 2 2013-07-22 19:00:00

# %% [markdown]
# Hence delays of 2 hours of more in arrival  is associated with a delay in departure of atleast 1 hour.

# %% [markdown]
# ### Were delayed by at least an hour, but made up over 30 minutes in flight

# %%
filter(flights,
       abs(dep_delay) > 59 & arr_delay < 30)
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013  1     3  1850     1745           65        2148     2120
# 2   2013  1     3  1950     1845           65        2228     2227
# 3   2013  1     3  2015     1915           60        2135     2111
# 4   2013  1     6  1019      900           79        1558     1530
# 5   2013  1     7  1543     1430           73        1758     1735
# 6   2013  1    11  1020      920           60        1311     1245
# 7   2013  1    12  1706     1600           66        1949     1927
# 8   2013  1    12  1953     1845           68        2154     2137
# 9   2013  1    19  1456     1355           61        1636     1615
# 10  2013  1    21  1531     1430           61        1843     1815
# 11  2013  1    21  1648     1545           63        1939     1910
# 12  2013  1    30  2100     2000           60        2207     2139
# 13  2013 10    10  1938     1835           63        2158     2148
# ...

# %%
count(filter(flights,
       abs(dep_delay) > 59 & arr_delay < 30))
# Out:
#   n
# 1 206

# %% [markdown]
# ### Departed between midnight and 6am (inclusive)

# %%
# filter_cond <- dep_time >= 0 & dep_time <=600
filter(flights, dep_time >= 0 & dep_time <= 600)
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1   517       515             2        830      819
# 2    2013 1     1   533       529             4        850      830
# 3    2013 1     1   542       540             2        923      850
# 4    2013 1     1   544       545            -1       1004     1022
# 5    2013 1     1   554       600            -6        812      837
# 6    2013 1     1   554       558            -4        740      728
# 7    2013 1     1   555       600            -5        913      854
# 8    2013 1     1   557       600            -3        709      723
# 9    2013 1     1   557       600            -3        838      846
# 10   2013 1     1   558       600            -2        753      745
# 11   2013 1     1   558       600            -2        849      851
# 12   2013 1     1   558       600            -2        853      856
# 13   2013 1     1   558       600            -2        924      917
# ...

# %%
count(filter(flights, dep_time >= 0 & dep_time <= 600))
# Out:
#   n
# 1 9344

# %% [markdown]
# ### How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %%
filter(flights, is.na(dep_time))
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1   NA       1630           NA        NA       1815
# 2    2013 1     1   NA       1935           NA        NA       2240
# 3    2013 1     1   NA       1500           NA        NA       1825
# 4    2013 1     1   NA        600           NA        NA        901
# 5    2013 1     2   NA       1540           NA        NA       1747
# 6    2013 1     2   NA       1620           NA        NA       1746
# 7    2013 1     2   NA       1355           NA        NA       1459
# 8    2013 1     2   NA       1420           NA        NA       1644
# 9    2013 1     2   NA       1321           NA        NA       1536
# 10   2013 1     2   NA       1545           NA        NA       1910
# 11   2013 1     2   NA       1330           NA        NA       1640
# 12   2013 1     2   NA       1601           NA        NA       1735
# 13   2013 1     3   NA        645           NA        NA        757
# ...

# %% [markdown]
# 8255 flights have missing dep time

# %%
count(filter(flights, is.na(dep_time)))
# Out:
#   n
# 1 8255

# %%
dd <- filter(flights, carrier == "EV" & flight == 4308)
dd[with(dd, order(year, month, day)), ]
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1      1    NA     1630            NA         NA     1815
# 2  2013 1      2  1806     1629            97       2008     1808
# 3  2013 2     28  2150     2117            33       2248     2231
# 4  2013 4     10  1326     1329            -3       1440     1436
# 5  2013 4     11    NA     1329            NA         NA     1436
# 6  2013 4     12  1553     1329           144       1657     1436
# 7  2013 4     13  1320     1329            -9       1430     1436
# 8  2013 4     14  1322     1329            -7       1433     1438
# 9  2013 4     15  1538     1329           129       1657     1436
# 10 2013 4     16  1320     1329            -9       1427     1436
# 11 2013 4     17  1324     1329            -5       1433     1436
# 12 2013 4     18  1344     1329            15       1457     1436
# 13 2013 4     19  1444     1329            75       1545     1436
# ...

# %%
dd <- filter(flights, carrier == "AA" & flight == 791)
dd[with(dd, order(year, month, day)), ]
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1      1    NA     1935            NA         NA     2240
# 2   2013 1      2  1924     1935           -11       2220     2240
# 3   2013 1      3  2036     1935            61       2345     2240
# 4   2013 1      4  1941     1935             6       2227     2240
# 5   2013 1      7  1927     1935            -8       2216     2240
# 6   2013 1      8  2024     1935            49       2333     2240
# 7   2013 1      9  1929     1935            -6       2224     2240
# 8   2013 1     10  1931     1935            -4       2215     2240
# 9   2013 1     11  2125     1935           110         12     2240
# 10  2013 1     14  1925     1935           -10       2252     2240
# 11  2013 1     15  1928     1935            -7       2241     2240
# 12  2013 1     16  1932     1935            -3       2240     2240
# 13  2013 1     17  2041     1935            66       2335     2240
# ...

# %%
filter(flights, carrier == "AA" & flight == 791 & is.na(dep_time))
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1      1  NA       1935           NA        NA       2240
# 2 2013 2      8  NA       1935           NA        NA       2240
# 3 2013 3      6  NA       1935           NA        NA       2240
# 4 2013 4     10  NA       1930           NA        NA       2230
# 5 2013 6     24  NA       1915           NA        NA       2205
# 6 2013 7     10  NA       1915           NA        NA       2205
# 7 2013 7     22  NA       1915           NA        NA       2205
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 NA        AA      791    N3EHAA  LGA    DFW  NA       1389     19   35
# 2 NA        AA      791    NA      LGA    DFW  NA       1389     19   35
# 3 NA        AA      791    N3CTAA  LGA    DFW  NA       1389     19   35
# 4 NA        AA      791    N3GKAA  LGA    DFW  NA       1389     19   30
# 5 NA        AA      791    N3CEAA  LGA    DFW  NA       1389     19   15
# ...

# %% [markdown]
# not sure why there are nan values
