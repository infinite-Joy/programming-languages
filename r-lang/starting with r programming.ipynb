# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
ggplot(iris, aes(x=Sepal.Length, y=Sepal.Width, color=Species)) + geom_point(size=3)
# Out:
# plot without title

# %%
library(tidyverse)
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  2.1.1     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
ggplot(data=mpg) + geom_point(mapping = aes(x=displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg)
# Out:
# plot without title

# %%
?mpg

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = hwy, y = cyl))
# Out:
# plot without title

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = class, y = drv))
# Out:
# plot without title

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %% [markdown]
# ### using the size argument the points can be marked with different sizes based on the class

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = displ, y = hwy, size = class))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# ### using the alpha argument the points can be marked and we will see different transparency based on the class

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = displ, y = hwy, alpha = class))
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# ### using the shape argument the points can be marked based on the class

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ### if you are writing in multiple lines, + should be in the previous line

# %%
ggplot(data = mpg) + 
    geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
    geom_point(mapping = aes(x = displ, y = hwy)) +
    facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
ggplot(data = mpg) + geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) + 
    geom_smooth(mapping = aes(x = displ, y = hwy)) + 
    geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
    geom_point(mapping = aes(color=class)) + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
diamonds
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 13    0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# ...

# %%
map_data('in')
# Out:
# Attaching package: ‘maps’
#
# The following object is masked from ‘package:purrr’:
#
#     map
# Error: 'inMapEnv' is not an exported object from 'namespace:maps'
# Traceback:
#
# 1. map_data("in")
# 2. maps::map(map, region, exact = exact, plot = FALSE, fill = TRUE,
#  .     ...)
# 3. maptype(database)
# 4. mapenvir(database)
# 5. paste0(Sys.getenv(eval(parse(text = dbname))), database)
# 6. Sys.getenv(eval(parse(text = dbname)))
# 7. eval(parse(text = dbname))
# 8. eval(parse(text = dbname))
# 9. maps::inMapEnv
# 10. getExportedValue(pkg, name)
# 11. stop(gettextf("'%s' is not an exported object from 'namespace:%s'",
#   .     name, getNamespaceName(ns)), call. = FALSE, domain = NA)
